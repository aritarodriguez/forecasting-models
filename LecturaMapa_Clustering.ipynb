# %% [markdown]
# <a href="https://colab.research.google.com/github/aritarodriguez/forecasting-models/blob/main/LecturaMapa_Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==========================================================
# POLÍGONO DE GUAYAQUIL - ETIQUETAR PUNTOS Y DESCARGAR RESULTADOS
# ==========================================================
# !pip install geopandas shapely folium fiona fastkml -q

import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import folium
from google.colab import files

# === 1️⃣ Leer los puntos del archivo Excel ===
df = pd.read_excel("TALLER FINAL.xlsx", sheet_name="Guayaquil")

# Limpiar encabezados
df.columns = df.columns.str.strip().str.upper().str.replace("\n", " ", regex=False)

# Detectar columnas con LAT / LON
col_lat = [c for c in df.columns if "LAT" in c][0]
col_lon = [c for c in df.columns if "LON" in c][0]

# Renombrar columnas
df = df.rename(columns={col_lat: "Latitud", col_lon: "Longitud"})

# Asegurar tipo numérico
df["Latitud"] = pd.to_numeric(df["Latitud"], errors="coerce")
df["Longitud"] = pd.to_numeric(df["Longitud"], errors="coerce")
df = df.dropna(subset=["Latitud", "Longitud"]).copy()

# === 2️⃣ Convertir a GeoDataFrame ===
gdf_points = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df["Longitud"], df["Latitud"]), crs="EPSG:4326")

# === 3️⃣ Leer el polígono desde tu archivo KML ===
poly_gdf = gpd.read_file("Guayaquil.kml", driver="KML").to_crs("EPSG:4326")
poly_gdf = poly_gdf[poly_gdf.geometry.type.isin(["Polygon", "MultiPolygon"])].copy()
poly_union = poly_gdf.unary_union

# === 4️⃣ Determinar si cada punto está dentro o fuera ===
gdf_points["Dentro_Poligono"] = gdf_points.geometry.apply(lambda p: "Sí" if poly_union.covers(p) else "No")

# === 5️⃣ Exportar resultados a Excel ===
output_excel = "puntos_con_flag.xlsx"
gdf_points.drop(columns=["geometry"]).to_excel(output_excel, index=False)

# === 6️⃣ Crear mapa Folium ===
m = folium.Map(location=[gdf_points["Latitud"].mean(), gdf_points["Longitud"].mean()],
               zoom_start=12, tiles="CartoDB positron")

# Agregar contorno del polígono
folium.GeoJson(
    poly_union,
    name="Polígono Guayaquil",
    style_function=lambda x: {"color": "#1f77b4", "weight": 2, "fillOpacity": 0.05}
).add_to(m)

# Agregar puntos (verde = dentro, rojo = fuera)
for _, row in gdf_points.iterrows():
    color = "#2ca02c" if row["Dentro_Poligono"] == "Sí" else "#d62728"
    popup_text = f"""
    <b>Sector:</b> {row.get('SECTOR','')}<br>
    <b>Local:</b> {row.get('NOMBRE DEL LOCAL','')}<br>
    <b>Lat:</b> {row['Latitud']:.5f}<br>
    <b>Lon:</b> {row['Longitud']:.5f}<br>
    <b>Dentro:</b> {row['Dentro_Poligono']}
    """
    folium.CircleMarker(
        location=[row["Latitud"], row["Longitud"]],
        radius=4,
        color=color,
        fill=True,
        fill_opacity=0.8,
        popup=folium.Popup(popup_text, max_width=300)
    ).add_to(m)

# Guardar mapa
output_map = "mapa_validacion.html"
m.save(output_map)

# === 7️⃣ Descargar ambos archivos ===
files.download(output_excel)
files.download(output_map)

print("✅ Proceso completado. Archivos descargados.")
m
# Out:
# /tmp/ipython-input-1393582203.py:36: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   poly_union = poly_gdf.unary_union
# ✅ Proceso completado. Archivos descargados.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_29212007309849ffa5e3af4dc2043edd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_29212007309849ffa5e3af4dc2043edd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_29212007309849ffa5e3af4dc2043edd = L.map(
#                 &quot;map_29212007309849ffa5e3af4dc2043edd&quot;,
#                 {
#                     center: [-2.1839746049655173, -79.89309480263448],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_15360c339f40c9b2e705fce06dab3fc7 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_15360c339f40c9b2e705fce06dab3fc7.addTo(map_29212007309849ffa5e3af4dc2043edd);
#
#
#         function geo_json_89f9bb3bc4bb243f4a80b96002139d8b_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.05, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_89f9bb3bc4bb243f4a80b96002139d8b_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_89f9bb3bc4bb243f4a80b96002139d8b = L.geoJson(null, {
#                 onEachFeature: geo_json_89f9bb3bc4bb243f4a80b96002139d8b_onEachFeature,
#
#                 style: geo_json_89f9bb3bc4bb243f4a80b96002139d8b_styler,
#             ...{
# }
#         });
#
#         function geo_json_89f9bb3bc4bb243f4a80b96002139d8b_add (data) {
#             geo_json_89f9bb3bc4bb243f4a80b96002139d8b
#                 .addData(data);
#         }
#             geo_json_89f9bb3bc4bb243f4a80b96002139d8b_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-79.9614342, -2.0649059, 0.0], [-79.9806603, -2.0971569, 0.0], [-79.9394615, -2.1417583, 0.0], [-79.9758538, -2.1904753, 0.0], [-79.9243553, -2.2988821, 0.0], [-79.8364647, -2.2741825, 0.0], [-79.8412712, -2.1609709, 0.0], [-79.8886498, -2.048437, 0.0], [-79.9614342, -2.0649059, 0.0]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_89f9bb3bc4bb243f4a80b96002139d8b.addTo(map_29212007309849ffa5e3af4dc2043edd);
#
#
#             var circle_marker_802c507b2020b69d6267f02a365be413 = L.circleMarker(
#                 [-2.185104, -79.889018],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ca02c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#2ca02c&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_29212007309849ffa5e3af4dc2043edd);
#
#
#         var popup_2fe1f9adbd76a4bf74457821e704cb7c = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_daeb2f29513c014b70af27ef08d88825 = $(`&lt;div id=&quot;html_daeb2f29513c014b70af27ef08d88825&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;Sector:&lt;/b&gt; 10 DE AGOSTO - SUCRE&lt;br&gt;     &lt;b&gt;Local:&lt;/b&gt; nan&lt;br&gt;     &lt;b&gt;Lat:&lt;/b&gt; -2.18510&lt;br&gt;     &lt;b&gt;Lon:&lt;/b&gt; -79.88902&lt;br&gt;     &lt;b&gt;Dentro:&lt;/b&gt; Sí     &lt;/div&gt;`)[0];
#                 popup_2fe1f9adbd76a4bf74457821e704cb7c.setContent(html_daeb2f29513c014b70af27ef08d88825);
#
#
#
#         circle_marker_802c507b2020b69d6267f02a365be413.bindPopup(popup_2fe1f9adbd76a4bf74457821e704cb7c)
#         ;
#
#
#
#
#             var circle_marker_3fab87afc0590b8a52668c63b04828d3 = L.circleMarker(
#                 [-2.185162, -79.889558],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ca02c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#2ca02c&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_29212007309849ffa5e3af4dc2043edd);

# %%
# ==========================================================
# CLUSTERING GEOGRÁFICO CON K-MEANS (Geocercas 50-150 clientes)
# ==========================================================
# !pip install pandas scikit-learn folium openpyxl -q

import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import folium
import math

# === 1️⃣ Leer el archivo con puntos geográficos ===
df = pd.read_excel("puntos_con_flag.xlsx")

# Asegurar columnas de coordenadas
df.columns = df.columns.str.strip().str.upper()
col_lat = [c for c in df.columns if "LAT" in c][0]
col_lon = [c for c in df.columns if "LON" in c][0]
col_id  = [c for c in df.columns if "N" in c][0]  # Columna ID del cliente (N°)

df = df.rename(columns={col_lat: "Latitud", col_lon: "Longitud", col_id: "ID"})
df = df.dropna(subset=["Latitud", "Longitud"]).copy()

# === 2️⃣ Determinar número óptimo de clústeres (entre 50-150 clientes por geocerca) ===
num_clientes = len(df)
clientes_por_cluster = 100  # promedio deseado
k = max(1, round(num_clientes / clientes_por_cluster))

print(f"Total clientes: {num_clientes}")
print(f"Número de clústeres estimado: {k}")

# === 3️⃣ Ejecutar K-Means ===
X = df[["Latitud", "Longitud"]].values
kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
df["Cluster"] = kmeans.fit_predict(X)

# === 4️⃣ Calcular centroides ===
centroids = pd.DataFrame(kmeans.cluster_centers_, columns=["Latitud", "Longitud"])
centroids["Cluster"] = range(k)

# === 5️⃣ Crear mapa Folium ===
map_center = [df["Latitud"].mean(), df["Longitud"].mean()]
m = folium.Map(location=map_center, zoom_start=11, tiles="CartoDB positron")

# Colores distintos por cluster
import random
random.seed(42)
colors = [f"#{random.randint(0,0xFFFFFF):06x}" for _ in range(k)]

for i, row in df.iterrows():
    c = colors[row["Cluster"] % len(colors)]
    popup_text = f"""
    <b>ID:</b> {row['ID']}<br>
    <b>Cluster:</b> {row['Cluster']}<br>
    <b>Latitud:</b> {row['Latitud']:.5f}<br>
    <b>Longitud:</b> {row['Longitud']:.5f}
    """
    folium.CircleMarker(
        location=[row["Latitud"], row["Longitud"]],
        radius=3,
        color=c,
        fill=True,
        fill_opacity=0.7,
        popup=popup_text
    ).add_to(m)

# Agregar los centroides
for _, row in centroids.iterrows():
    folium.Marker(
        location=[row["Latitud"], row["Longitud"]],
        icon=folium.Icon(color="red", icon="flag", prefix="fa"),
        popup=f"Centro Cluster {row['Cluster']}"
    ).add_to(m)

# Guardar mapa
m.save("mapa_clusters.html")

# === 6️⃣ Guardar resultados ===
output_excel = "clientes_clusterizados.xlsx"
df.to_excel(output_excel, index=False)

print("✅ Clustering completado.")
print(f"Archivo generado: {output_excel}")
print("Mapa interactivo: mapa_clusters.html")

# Mostrar mapa en Colab
m
# Out:
# Total clientes: 725
# Número de clústeres estimado: 7
# ✅ Clustering completado.
# Archivo generado: clientes_clusterizados.xlsx
# Mapa interactivo: mapa_clusters.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1071f035f214f5ef976836483fd841fe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1071f035f214f5ef976836483fd841fe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1071f035f214f5ef976836483fd841fe = L.map(
#                 &quot;map_1071f035f214f5ef976836483fd841fe&quot;,
#                 {
#                     center: [-2.1839746049655173, -79.89309480263448],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f6427a6e948d18b7f33d4571d1085cfc = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f6427a6e948d18b7f33d4571d1085cfc.addTo(map_1071f035f214f5ef976836483fd841fe);
#
#
#             var circle_marker_79f5beb41fe6e6e6b0a1aa5342b4c685 = L.circleMarker(
#                 [-2.185104, -79.889018],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#7d6277&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#7d6277&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1071f035f214f5ef976836483fd841fe);
#
#
#         var popup_6272013d9c4456854777f4d789a22b6f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c5a6cc9f955624e8743e66c6b2a4d0e6 = $(`&lt;div id=&quot;html_c5a6cc9f955624e8743e66c6b2a4d0e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;ID:&lt;/b&gt; 1&lt;br&gt;     &lt;b&gt;Cluster:&lt;/b&gt; 3&lt;br&gt;     &lt;b&gt;Latitud:&lt;/b&gt; -2.18510&lt;br&gt;     &lt;b&gt;Longitud:&lt;/b&gt; -79.88902     &lt;/div&gt;`)[0];
#                 popup_6272013d9c4456854777f4d789a22b6f.setContent(html_c5a6cc9f955624e8743e66c6b2a4d0e6);
#
#
#
#         circle_marker_79f5beb41fe6e6e6b0a1aa5342b4c685.bindPopup(popup_6272013d9c4456854777f4d789a22b6f)
#         ;
#
#
#
#
#             var circle_marker_43ecc4094c2586940cca28160e62f207 = L.circleMarker(
#                 [-2.185162, -79.889558],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#7d6277&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#7d6277&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1071f035f214f5ef976836483fd841fe);
#
#
#         var popup_2c5b834c878a5559077c427b02a5dbd4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d187a45970a3ea712f11a19c09adbcb = $(`&lt;div id=&quot;html_8d187a45970a3ea712f11a19c09adbcb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;b&gt;ID:&lt;/b&gt; 2&lt;br&gt;     &lt;b&gt;Cluster:&lt;/b&gt; 3&lt;br&gt;     &lt;b&gt;Latitud:&lt;/b&gt; -2.18516&lt;br&gt;     &lt;b&gt;Longitud:&lt;/b&gt; -79.88956     &lt;/div&gt;`)[0];
#                 popup_2c5b834c878a5559077c427b02a5dbd4.setContent(html_8d187a45970a3ea712f11a19c09adbcb);
#
#
#
#         circle_marker_43ecc4094c2586940cca28160e62f207.bindPopup(popup_2c5b834c878a5559077c427b02a5dbd4)
#         ;
#
#
#
#
#             var circle_marker_b3611dad029a7e44d94a5c6d003f11f5 = L.circleMarker(
#                 [-2.18920782, -79.88957539],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#7d6277&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#7d6277&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1071f035f214f5ef976836483fd841fe);
#
#
#         var popup_c200c48b4f7eb60aaaab441c93b88c60 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a88e2b938a26c6f46e17b5256a23f8
